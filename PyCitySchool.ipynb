# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# File to load
students_complete_df = pd.read_csv('students_complete.csv')
schools_complete_df = pd.read_csv('schools_complete.csv')

# %%
# Read Students data
'students_complete_df'
# Out:
# 'students_complete_df'

# %%
# Read School data
schools_complete_df
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# 14         14     Thomas High School   Charter  1635  1043130

# %%
# Merging data into single Dataset
combine_df = pd.merge(students_complete_df,schools_complete_df, how="outer", on="school_name")

# %%
combine_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %%
# Calculating the total number of schools 
schools_count = len(combine_df["school_name"].unique())
schools_count
# Out:
# 15

# %%
#Calculating the total number of students
total_student_count = combined_df["student_name"].count()
total_student_count
# Out:
# 39170

# %%
# Calculating the total budget
total_budget = sum(combined_df["budget"].unique())
total_budget
# Out:
# 24649428

# %%
# Calculating the average math score
average_mathscore = combined_df["math_score"].mean()
average_mathscore
# Out:
# 78.98537145774827

# %%
# Calculating the average reading score
average_readingscore= combined_df["reading_score"].mean()
average_readingscore
# Out:
# 81.87784018381414

# %%
# Calculating the percentage of students with a passing math score (70 or greater)
percent_mathscore= combine_df.query('reading_score >= 70').math_score.count() / combined_df["reading_score"].count() * 100
percent_mathscore
# Out:
# 85.80546336482001

# %%
# Calculating the percentage of students with a passing reading score (70 or greater)
percent_readingscore= combine_df.query('math_score >= 70').math_score.count() / combined_df["math_score"].count() * 100
percent_readingscore
# Out:
# 74.9808526933878

# %%
# Calculating the percentage of students who passed math and reading (% Overall Passing)
overall_score=combined_df[(combined_df["reading_score"]>= 70) & (combined_df["math_score"]>=70)].count()
overall_score
# Out:
# Student ID       25528
# student_name     25528
# gender           25528
# grade            25528
# school_name      25528
# reading_score    25528
# math_score       25528
# School ID        25528
# type             25528
# size             25528
# budget           25528
# dtype: int64

# %%
total_combined_per = combined_df[(combined_df["reading_score"]>= 70) & (combined_df["math_score"]>=70)].count()["student_name"]/total_student_count * 100
total_combined_per
# Out:
# 65.17232575950983

# %%
# Creating a Dataframe to hold the above results

df = pd.DataFrame([{"Total Scchool":schools_count,"Total Students":total_student_count, 
                   "Total Budget":total_budget, "Average Math Score":average_mathscore,
                    "Average Reading Score":average_readingscore, "% Passing Math":percent_mathscore,
                   "% Passing Reading":percent_readingscore, "% Overall Passing":total_combined_per
                   
                   
                   }])
df
# Out:
#    Total Scchool  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       85.805463          74.980853          65.172326

# %% [markdown]
# # School Summary

# %%
# School Name Summary
school_name= combine_df["school_name"].unique()
school_name
# Out:
# array(['Huang High School', 'Figueroa High School', 'Shelton High School',
#        'Hernandez High School', 'Griffin High School',
#        'Wilson High School', 'Cabrera High School', 'Bailey High School',
#        'Holden High School', 'Pena High School', 'Wright High School',
#        'Rodriguez High School', 'Johnson High School', 'Ford High School',
#        'Thomas High School'], dtype=object)

# %%
# Total Students Summary
count_by_school= combine_df["school_name"].value_counts()
count_by_school
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
# Total Budget Summary per school
total_budget_summary = combined_df.groupby(["school_name"]).mean()["budget"]
total_budget_summary
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
#Per capita spending
per_capita = total_budget_summary/count_by_school
per_capita
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# School Type Summary
combined_df["type"].unique()
# Out:
# array(['District', 'Charter'], dtype=object)

# %%
count_by_school = combined_df["school_name"].value_counts()
count_by_school
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
# Average Math Score
per_school_math = combined_df.groupby(["school_name"]).mean()["math_score"]
per_school_math
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#total passing scores

per_school_math_passing = combined_df[combined_df["math_score"]>=70].groupby("school_name").count()["math_score"]
per_school_math_passing
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: math_score, dtype: int64

# %%
per_school_reading_passing = combined_df[combined_df["reading_score"]>=70].groupby("school_name").count()["reading_score"]
per_school_reading_passing
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: reading_score, dtype: int64

# %%
# Average Reading Score
avg_reading= combined_df.groupby(["school_name"]).mean()["reading_score"]
avg_reading
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# % Passing Math
percent_math= per_school_math_passing/count_by_school *100
percent_math
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
# % Passing Reading
percent_reading = per_school_reading_passing/count_by_school *100
percent_reading
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
# % Overall Passing
percent_overall = (per_school_reading_passing + per_school_math_passing) / (39170) * 100
percent_overall
# Out:
# school_name
# Bailey High School       18.879244
# Cabrera High School       9.068164
# Figueroa High School     11.046719
# Ford High School         10.321675
# Griffin High School       7.140669
# Hernandez High School    17.467450
# Holden High School        2.057697
# Huang High School        10.947153
# Johnson High School      17.901455
# Pena High School          4.679602
# Rodriguez High School    14.965535
# Shelton High School       8.529487
# Thomas High School        7.955068
# Wilson High School       11.097779
# Wright High School        8.728619
# dtype: float64

# %%
df = pd.read_excel("/Users/ola/Desktop/PyCitySchools/school_summary.xlsx")

df
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 0      Bailey High School     Charter            4976              3124928
# 1     Cabrera High School    District            1858              1081356
# 2    Figueroa High School     Charter            2949              1884411
# 3        Ford High School     Charter            2739              1763916
# 4     Griffin High School    District            1468               917500
# 5   Hernandez High School     Charter            4635              3022020
# 6      Holden High School    District             427               248087
# 7       Huang High School    District            2917              1910635
# 8     Johnson High School    District            4761              3094650
# 9        Pena High School     Charter             962               585858
# 10  Rodriguez High School     Charter            3999              2547363
# 11    Shelton High School    District            1761              1056600
# 12     Thomas High School    District            1635              1043130
# 13     Wilson High School     Charter            2283              1319574
# 14     Wright High School    District            1800              1049400
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 0                  628           77.048432              81.033963
# 1                  582           83.061895              83.975780
# 2                  639           76.711767              81.158020
# 3                  644           77.102592              80.746258
# 4                  625           83.351499              83.816757
# 5                  652           77.289752              80.934412
# 6                  581           83.803279              83.814988
# 7                  655           76.629414              81.182722
# 8                  650           77.072464              80.966394
# 9                  609           83.839917              84.044699
# 10                 637           76.842711              80.744686
# 11                 600           83.359455              83.725724
# 12                 638           83.418349              83.848930
# 13                 578           83.274201              83.989488
# 14                 583           83.682222              83.955000
#
#     % Passing Math  % Passing Reading
# 0        66.680064          81.933280
# 1        94.133477          97.039828
# 2        65.988471          80.739234
# 3        68.309602          79.299014
# 4        93.392371          97.138965
# 5        66.752967          80.862999
# 6        92.505855          96.252927
# 7        65.683922          81.316421
# 8        66.057551          81.222432
# 9        94.594595          95.945946
# 10       66.366592          80.220055
# 11       93.867121          95.854628
# 12       93.272171          97.308869
# 13       93.867718          96.539641
# 14       93.333333          96.611111

# %%
df.style.format({'Total Budget': "${:.2f}", 'Per Student Budget': '${:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_4c684">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c684_level0_col0" class="col_heading level0 col0" >School Name</th>
#       <th id="T_4c684_level0_col1" class="col_heading level0 col1" >School Type</th>
#       <th id="T_4c684_level0_col2" class="col_heading level0 col2" >Total Students</th>
#       <th id="T_4c684_level0_col3" class="col_heading level0 col3" >Total School Budget</th>
#       <th id="T_4c684_level0_col4" class="col_heading level0 col4" >Per Student Budget</th>
#       <th id="T_4c684_level0_col5" class="col_heading level0 col5" >Average Math Score</th>
#       <th id="T_4c684_level0_col6" class="col_heading level0 col6" >Average Reading Score</th>
#       <th id="T_4c684_level0_col7" class="col_heading level0 col7" >% Passing Math</th>
#       <th id="T_4c684_level0_col8" class="col_heading level0 col8" >% Passing Reading</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c684_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c684_row0_col0" class="data row0 col0" >Bailey High School</td>
#       <td id="T_4c684_row0_col1" class="data row0 col1" >Charter</td>
#       <td id="T_4c684_row0_col2" class="data row0 col2" >4976</td>
#       <td id="T_4c684_row0_col3" class="data row0 col3" >3124928</td>
#       <td id="T_4c684_row0_col4" class="data row0 col4" >$628.00</td>
#       <td id="T_4c684_row0_col5" class="data row0 col5" >77.048432</td>
#       <td id="T_4c684_row0_col6" class="data row0 col6" >81.033963</td>
#       <td id="T_4c684_row0_col7" class="data row0 col7" >66.680064</td>
#       <td id="T_4c684_row0_col8" class="data row0 col8" >81.933280</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c684_row1_col0" class="data row1 col0" >Cabrera High School</td>
#       <td id="T_4c684_row1_col1" class="data row1 col1" >District</td>
#       <td id="T_4c684_row1_col2" class="data row1 col2" >1858</td>
#       <td id="T_4c684_row1_col3" class="data row1 col3" >1081356</td>
#       <td id="T_4c684_row1_col4" class="data row1 col4" >$582.00</td>
#       <td id="T_4c684_row1_col5" class="data row1 col5" >83.061895</td>
#       <td id="T_4c684_row1_col6" class="data row1 col6" >83.975780</td>
#       <td id="T_4c684_row1_col7" class="data row1 col7" >94.133477</td>
#       <td id="T_4c684_row1_col8" class="data row1 col8" >97.039828</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c684_row2_col0" class="data row2 col0" >Figueroa High School</td>
#       <td id="T_4c684_row2_col1" class="data row2 col1" >Charter</td>
#       <td id="T_4c684_row2_col2" class="data row2 col2" >2949</td>
#       <td id="T_4c684_row2_col3" class="data row2 col3" >1884411</td>
#       <td id="T_4c684_row2_col4" class="data row2 col4" >$639.00</td>
#       <td id="T_4c684_row2_col5" class="data row2 col5" >76.711767</td>
#       <td id="T_4c684_row2_col6" class="data row2 col6" >81.158020</td>
#       <td id="T_4c684_row2_col7" class="data row2 col7" >65.988471</td>
#       <td id="T_4c684_row2_col8" class="data row2 col8" >80.739234</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c684_row3_col0" class="data row3 col0" >Ford High School</td>
#       <td id="T_4c684_row3_col1" class="data row3 col1" >Charter</td>
#       <td id="T_4c684_row3_col2" class="data row3 col2" >2739</td>
#       <td id="T_4c684_row3_col3" class="data row3 col3" >1763916</td>
#       <td id="T_4c684_row3_col4" class="data row3 col4" >$644.00</td>
#       <td id="T_4c684_row3_col5" class="data row3 col5" >77.102592</td>
#       <td id="T_4c684_row3_col6" class="data row3 col6" >80.746258</td>
#       <td id="T_4c684_row3_col7" class="data row3 col7" >68.309602</td>
#       <td id="T_4c684_row3_col8" class="data row3 col8" >79.299014</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c684_row4_col0" class="data row4 col0" >Griffin High School</td>
#       <td id="T_4c684_row4_col1" class="data row4 col1" >District</td>
#       <td id="T_4c684_row4_col2" class="data row4 col2" >1468</td>
#       <td id="T_4c684_row4_col3" class="data row4 col3" >917500</td>
#       <td id="T_4c684_row4_col4" class="data row4 col4" >$625.00</td>
#       <td id="T_4c684_row4_col5" class="data row4 col5" >83.351499</td>
#       <td id="T_4c684_row4_col6" class="data row4 col6" >83.816757</td>
#       <td id="T_4c684_row4_col7" class="data row4 col7" >93.392371</td>
#       <td id="T_4c684_row4_col8" class="data row4 col8" >97.138965</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c684_row5_col0" class="data row5 col0" >Hernandez High School</td>
#       <td id="T_4c684_row5_col1" class="data row5 col1" >Charter</td>
#       <td id="T_4c684_row5_col2" class="data row5 col2" >4635</td>
#       <td id="T_4c684_row5_col3" class="data row5 col3" >3022020</td>
#       <td id="T_4c684_row5_col4" class="data row5 col4" >$652.00</td>
#       <td id="T_4c684_row5_col5" class="data row5 col5" >77.289752</td>
#       <td id="T_4c684_row5_col6" class="data row5 col6" >80.934412</td>
#       <td id="T_4c684_row5_col7" class="data row5 col7" >66.752967</td>
#       <td id="T_4c684_row5_col8" class="data row5 col8" >80.862999</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c684_row6_col0" class="data row6 col0" >Holden High School</td>
#       <td id="T_4c684_row6_col1" class="data row6 col1" >District</td>
#       <td id="T_4c684_row6_col2" class="data row6 col2" >427</td>
#       <td id="T_4c684_row6_col3" class="data row6 col3" >248087</td>
#       <td id="T_4c684_row6_col4" class="data row6 col4" >$581.00</td>
#       <td id="T_4c684_row6_col5" class="data row6 col5" >83.803279</td>
#       <td id="T_4c684_row6_col6" class="data row6 col6" >83.814988</td>
#       <td id="T_4c684_row6_col7" class="data row6 col7" >92.505855</td>
#       <td id="T_4c684_row6_col8" class="data row6 col8" >96.252927</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c684_row7_col0" class="data row7 col0" >Huang High School</td>
#       <td id="T_4c684_row7_col1" class="data row7 col1" >District</td>
#       <td id="T_4c684_row7_col2" class="data row7 col2" >2917</td>
#       <td id="T_4c684_row7_col3" class="data row7 col3" >1910635</td>
#       <td id="T_4c684_row7_col4" class="data row7 col4" >$655.00</td>
#       <td id="T_4c684_row7_col5" class="data row7 col5" >76.629414</td>
#       <td id="T_4c684_row7_col6" class="data row7 col6" >81.182722</td>
#       <td id="T_4c684_row7_col7" class="data row7 col7" >65.683922</td>
#       <td id="T_4c684_row7_col8" class="data row7 col8" >81.316421</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4c684_row8_col0" class="data row8 col0" >Johnson High School</td>
#       <td id="T_4c684_row8_col1" class="data row8 col1" >District</td>
#       <td id="T_4c684_row8_col2" class="data row8 col2" >4761</td>
#       <td id="T_4c684_row8_col3" class="data row8 col3" >3094650</td>
#       <td id="T_4c684_row8_col4" class="data row8 col4" >$650.00</td>
#       <td id="T_4c684_row8_col5" class="data row8 col5" >77.072464</td>
#       <td id="T_4c684_row8_col6" class="data row8 col6" >80.966394</td>
#       <td id="T_4c684_row8_col7" class="data row8 col7" >66.057551</td>
#       <td id="T_4c684_row8_col8" class="data row8 col8" >81.222432</td>
#     </tr>
#     <tr>
#       <th id="T_4c684_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4c684_row9_col0" class="data row9 col0" >Pena High School</td>
#       <td id="T_4c684_row9_col1" class="data row9 col1" >Charter</td>
#       <td id="T_4c684_row9_col2" class="data row9 col2" >962</td>
#       <td id="T_4c684_row9_col3" class="data row9 col3" >585858</td>
#       <t

# %% [markdown]
# # Top Performing Schools (By % Overall Passing)

# %%
df
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 0      Bailey High School     Charter            4976              3124928
# 1     Cabrera High School    District            1858              1081356
# 2    Figueroa High School     Charter            2949              1884411
# 3        Ford High School     Charter            2739              1763916
# 4     Griffin High School    District            1468               917500
# 5   Hernandez High School     Charter            4635              3022020
# 6      Holden High School    District             427               248087
# 7       Huang High School    District            2917              1910635
# 8     Johnson High School    District            4761              3094650
# 9        Pena High School     Charter             962               585858
# 10  Rodriguez High School     Charter            3999              2547363
# 11    Shelton High School    District            1761              1056600
# 12     Thomas High School    District            1635              1043130
# 13     Wilson High School     Charter            2283              1319574
# 14     Wright High School    District            1800              1049400
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 0                  628           77.048432              81.033963
# 1                  582           83.061895              83.975780
# 2                  639           76.711767              81.158020
# 3                  644           77.102592              80.746258
# 4                  625           83.351499              83.816757
# 5                  652           77.289752              80.934412
# 6                  581           83.803279              83.814988
# 7                  655           76.629414              81.182722
# 8                  650           77.072464              80.966394
# 9                  609           83.839917              84.044699
# 10                 637           76.842711              80.744686
# 11                 600           83.359455              83.725724
# 12                 638           83.418349              83.848930
# 13                 578           83.274201              83.989488
# 14                 583           83.682222              83.955000
#
#     % Passing Math  % Passing Reading
# 0        66.680064          81.933280
# 1        94.133477          97.039828
# 2        65.988471          80.739234
# 3        68.309602          79.299014
# 4        93.392371          97.138965
# 5        66.752967          80.862999
# 6        92.505855          96.252927
# 7        65.683922          81.316421
# 8        66.057551          81.222432
# 9        94.594595          95.945946
# 10       66.366592          80.220055
# 11       93.867121          95.854628
# 12       93.272171          97.308869
# 13       93.867718          96.539641
# 14       93.333333          96.611111

# %% [markdown]
# # Bottom Performing Schools (By % Overall Passing)
